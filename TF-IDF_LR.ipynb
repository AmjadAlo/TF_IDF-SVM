# %% [markdown]
#                                                     TF-IDF with leainer regration

# %%
import re
import string
import pandas as pd
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# Download NLTK stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Load dataset
df = pd.read_csv("data.csv")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Hano\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(df.columns)
# Out:
# Index(['label', 'title', 'text', 'subject', 'date'], dtype='object')

# %%
# Apply text preprocessing

df["text_clean"] = df["text"].str.lower()
df["text_clean"] = df["text_clean"].str.replace(r'\d+', '', regex=True)
df["text_clean"] = df["text_clean"].str.translate(str.maketrans('', '', string.punctuation))
df["text_clean"] = df["text_clean"].apply(lambda text: ' '.join([word for word in text.split() if word not in stop_words]))

# %%
#lemmatization
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Apply stemming
df["text_clean"] = df["text_clean"].apply(lambda text: ' '.join([stemmer.stem(word) for word in text.split()]))

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(df["text_clean"], df["label"], test_size=0.2, random_state=42)

# %%
print(df["text_clean"])  # Show first 5 rows
# Out:
# 0        washington reuter head conserv republican fact...
# 1        washington reuter transgend peopl allow first ...
# 2        washington reuter special counsel investig lin...
# 3        washington reuter trump campaign advis georg p...
# 4        seattlewashington reuter presid donald trump c...
#                                ...
# 39937    left organ decad georg soro fund chao occupi w...
# 39938    monica crowley offer brilliant polit analysi c...
# 39939    protest underway charlott thing got complet ha...
# 39940    local charlott nc news station wsoctv report s...
# 39941    divid america obama legaci hillari continu pro...
# Name: text_clean, Length: 39942, dtype: object

# %%
print(X_train[:5])  # Show first 5 rows
# Out:
# 38232    minneapoli mayor candid raymond dehn propos di...
# 17455    beij reuter china rule communist parti agre am...
# 15433    riyadh reuter major gulf stock market slid tue...
# 30412    presid trump deputi assist sebastian gorka app...
# 22452    amateur presid donald trump routin propag fake...
# Name: text_clean, dtype: object

# %%
print(y_train[:5])  # Show first 5 rows
# Out:
# 38232    0
# 17455    1
# 15433    1
# 30412    0
# 22452    0
# Name: label, dtype: int64

# %%
y_train.head
# Out:
# <bound method NDFrame.head of 38232    0
# 17455    1
# 15433    1
# 30412    0
# 22452    0
#         ..
# 6265     1
# 11284    1
# 38158    0
# 860      1
# 15795    1
# Name: label, Length: 31953, dtype: int64>

# %%
# TF-IDF with unigrams & bigrams
vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_features=50000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
print(X_test_tfidf[:5])
# Out:
#   (0, 54)	0.04065789776714216
#   (0, 420)	0.01810476848689177
#   (0, 517)	0.0161254958356478
#   (0, 612)	0.1012376904932948
#   (0, 620)	0.015803146015566365
#   (0, 698)	0.040851059964260264
#   (0, 729)	0.027685065866703423
#   (0, 757)	0.021056694110291853
#   (0, 886)	0.0179690524409619
#   (0, 887)	0.045015622217397716
#   (0, 1271)	0.020437576607985175
#   (0, 1307)	0.03358625827785119
#   (0, 1413)	0.01813536532931706
#   (0, 1442)	0.03271446683154046
#   (0, 1516)	0.038353445831579874
#   (0, 1535)	0.04712316097353152
#   (0, 1703)	0.038353445831579874
#   (0, 1841)	0.027054686893254368
#   (0, 2078)	0.07811512110051472
#   (0, 2082)	0.0733056422232575
#   (0, 2655)	0.027645177992471136
#   (0, 2935)	0.028832449227084438
#   (0, 2942)	0.02411088223376812
#   (0, 3146)	0.021154136410020473
#   (0, 3147)	0.024180309255191372
#   :	:
#   (4, 46769)	0.0537796200358764
#   (4, 47398)	0.04266333092612436
#   (4, 47428)	0.07564991692249555
#   (4, 47452)	0.0620729821860132
# ...

# %%
# Train Logistic Regression Model
model = LogisticRegression(max_iter=500)
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
# Evaluate
y_pred = model.predict(X_test_tfidf)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")
# Out:
# Model Accuracy: 0.9911

# %%
from sklearn.metrics import f1_score

# Assuming you already have actual and predicted labels
f1 = f1_score(y_test, y_pred, average='weighted')

# Print the F1-score
print("F1 Score:", f1)
# Out:
# F1 Score: 0.9911126592060445

# %%
'''Summary of the Workflow
Load the dataset (data.csv).
Clean the text (lowercasing, remove punctuation, numbers, and stopwords).
Split the data into training and testing sets.
Convert text to numerical vectors using TF-IDF.
Train a Logistic Regression model on the processed text.
Predict and evaluate the model’s accuracy.'''
# Out:
# 'Summary of the Workflow\nLoad the dataset (data.csv).\nClean the text (lowercasing, remove punctuation, numbers, and stopwords).\nSplit the data into training and testing sets.\nConvert text to numerical vectors using TF-IDF.\nTrain a Logistic Regression model on the processed text.\nPredict and evaluate the model’s accuracy.'

# %%
from sklearn.model_selection import train_test_split , learning_curve
import matplotlib.pyplot as plt

# %%
import json

accuracy = 0.9911 
with open("accuracy_TF-IDF_LR.json", "w") as f:
    json.dump({"accuracy": accuracy}, f)
